# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍

# %% [markdown]
# Geogebra Explanation Video recording link:-https://1drv.ms/v/s!Ap4mXYr_YuhTvn3jfN7k9UELvUXH?e=gBPgEj

# %% [markdown]
# Importing Required libraries

# %%
# Imporing all the necessary libraries
import numpy as np # Numerical operations on arrays and matrices
import pandas as pd #  Data manipulation and analysis
import matplotlib.pyplot as plt #  Data visualization (basic plots).
import seaborn as sns # Statistical data visualization (built on top of Matplotlib).

# %% [markdown]
# Data Set Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
supermarket_df=pd.read_csv('/content/drive/MyDrive/Superstore Marketing Data - Sheet1.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#First View
supermarket_df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %%
# Copying the date set
s_df=supermarket_df.copy()
s_df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %%
#selected values randomly
s_df.sample(n=5)
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 676    3578        1949  Graduation       Divorced  49160.0        0
# 11     5642        1979      Master       Together  62499.0        1
# 2156  10492        1959  Graduation       Together  38285.0        2
# 1871   3722        1972  Graduation         Single  44503.0        1
# 1153   5517        1969  Graduation        Married  25293.0        1
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 676          1  10/20/2013       29       122  ...               25
# 11           0    ########        0       140  ...                0
# 2156         1   6/24/2014       96         2  ...                2
# 1871         1   4/16/2014       83        31  ...                0
# 1153         0   9/15/2013       51        15  ...                0
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# ...

# %% [markdown]
# ## **Task 1:-**

# %%
# Dataset Rows & Columns count
s_df.shape
# Out:
# (2240, 22)

# %%
# Dataset Info
s_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
# Dataset Duplicate Value Count
s_df.duplicated().value_counts()
# Out:
# False    2240
# dtype: int64

# %% [markdown]
# As we can see in the data set no duplicate value is present

# %%
# Missing Values/Null Values Count
s_df.isna().sum().sort_values(ascending=False)
# Out:
# Income                 24
# Id                      0
# MntFishProducts         0
# Response                0
# NumWebVisitsMonth       0
# NumStorePurchases       0
# NumCatalogPurchases     0
# NumWebPurchases         0
# NumDealsPurchases       0
# MntGoldProds            0
# MntSweetProducts        0
# MntMeatProducts         0
# Year_Birth              0
# MntFruits               0
# MntWines                0
# Recency                 0
# Dt_Customer             0
# Teenhome                0
# Kidhome                 0
# Marital_Status          0
# Education               0
# Complain                0
# dtype: int64

# %% [markdown]
# For  Income column only 24 missing value is present

# %%
# Dataset Columns
list(s_df.columns)
# Out:
# ['Id',
#  'Year_Birth',
#  'Education',
#  'Marital_Status',
#  'Income',
#  'Kidhome',
#  'Teenhome',
#  'Dt_Customer',
#  'Recency',
#  'MntWines',
#  'MntFruits',
#  'MntMeatProducts',
#  'MntFishProducts',
#  'MntSweetProducts',
#  'MntGoldProds',
#  'NumDealsPurchases',
#  'NumWebPurchases',
#  'NumCatalogPurchases',
#  'NumStorePurchases',
#  'NumWebVisitsMonth',
#  'Response',
#  'Complain']

# %%
# Dataset Describe
s_df.describe().T
# Out:
#                       count          mean           std     min       25%  \
# Id                   2240.0   5592.159821   3246.662198     0.0   2828.25
# Year_Birth           2240.0   1968.805804     11.984069  1893.0   1959.00
# Income               2216.0  52247.251354  25173.076661  1730.0  35303.00
# Kidhome              2240.0      0.444196      0.538398     0.0      0.00
# Teenhome             2240.0      0.506250      0.544538     0.0      0.00
# Recency              2240.0     49.109375     28.962453     0.0     24.00
# MntWines             2240.0    303.935714    336.597393     0.0     23.75
# MntFruits            2240.0     26.302232     39.773434     0.0      1.00
# MntMeatProducts      2240.0    166.950000    225.715373     0.0     16.00
# MntFishProducts      2240.0     37.525446     54.628979     0.0      3.00
# MntSweetProducts     2240.0     27.062946     41.280498     0.0      1.00
# MntGoldProds         2240.0     44.021875     52.167439     0.0      9.00
# ...

# %%
# Check Unique Values for each variable.
s_df.nunique().sort_values(ascending=False)
# Out:
# Id                     2240
# Income                 1974
# MntWines                776
# MntMeatProducts         558
# Dt_Customer             401
# MntGoldProds            213
# MntFishProducts         182
# MntSweetProducts        177
# MntFruits               158
# Recency                 100
# Year_Birth               59
# NumWebVisitsMonth        16
# NumWebPurchases          15
# NumDealsPurchases        15
# NumStorePurchases        14
# NumCatalogPurchases      14
# Marital_Status            8
# Education                 5
# Kidhome                   3
# Teenhome                  3
# Response                  2
# Complain                  2
# dtype: int64

# %%
#Replaced ###### values with 0
s_df['Dt_Customer']=s_df['Dt_Customer'].replace('########', 0)

# %%
# Impute the missing values with the mean in the Income column
s_df.Income.fillna(s_df['Income'].median(),inplace=True)
#Changing Dt_customer data type from object to date time
s_df['Dt_Customer'] = pd.to_datetime(s_df['Dt_Customer'])

# %%
# Checking the count of null values in remaining columns.
s_df.isna().sum().sort_values(ascending=False)
# Out:
# Id                     0
# Year_Birth             0
# Response               0
# NumWebVisitsMonth      0
# NumStorePurchases      0
# NumCatalogPurchases    0
# NumWebPurchases        0
# NumDealsPurchases      0
# MntGoldProds           0
# MntSweetProducts       0
# MntFishProducts        0
# MntMeatProducts        0
# MntFruits              0
# MntWines               0
# Recency                0
# Dt_Customer            0
# Teenhome               0
# Kidhome                0
# Income                 0
# Marital_Status         0
# Education              0
# Complain               0
# dtype: int64

# %%
# Summary of cleaned dataset
print(s_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2240 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   datetime64[ns]
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
# Distribution of numerical variables
s_df.hist(figsize=(15, 15))
plt.show()

# %%
# Distribution of categorical variables
import plotly.express as px
# Count the occurrences of each food type
Education_distribution = s_df['Education'].value_counts().reset_index()

# Create a pie chart
fig = px.pie(Education_distribution, names='index', values='Education', title='Education Distribution')

# Customize the figure size
fig.update_layout(
    title_text='Education Distribution',
    width=800,    # Set the width of the figure
    height=600,   # Set the height of the figure
    paper_bgcolor='white',  # Set the background color
    plot_bgcolor='black'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From the pie chart we can clearly see that percentage of graduation level students are high as compared to other category of student.

# %%
# Customer Demographics
sns.histplot(x='Year_Birth', data=s_df, bins=30, kde=True)
plt.show()

sns.countplot(x='Marital_Status', data=s_df)
plt.show()

# %% [markdown]
# Based on the charts above, we can infer that the majority of the consumers in the dataset were married and that their birth years fell between 1960 and 1980.

# %%
#Distribution of Target variable
import seaborn as sns
sns.countplot(x='Response',data=s_df)
plt.show()
# Out:
# <Axes: xlabel='Response', ylabel='count'>

# %% [markdown]
# The dataset illustrates that the number of customers who declined the offer during the last campaign is high, and they dominate the ones who accepted it.

# %%
# Correlation matrix
correlation_matrix = s_df.corr()
plt.figure(figsize=(20,10))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.show()
# Out:
# <ipython-input-277-0d1a3a41e514>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# ## **Task 2**

# %%
# Descriptive statistics for key variables
key_variables = ['Year_Birth', 'Income', 'MntFishProducts', 'NumWebVisitsMonth']

# %%
# Calculate measures of central tendency and dispersion
statistics = s_df[key_variables].describe()
statistics
# Out:
#         Year_Birth         Income  MntFishProducts  NumWebVisitsMonth
# count  2240.000000    2240.000000      2240.000000        2240.000000
# mean   1968.805804   52237.975446        37.525446           5.316518
# std      11.984069   25037.955891        54.628979           2.426645
# min    1893.000000    1730.000000         0.000000           0.000000
# 25%    1959.000000   35538.750000         3.000000           3.000000
# 50%    1970.000000   51381.500000        12.000000           6.000000
# 75%    1977.000000   68289.750000        50.000000           7.000000
# max    1996.000000  666666.000000       259.000000          20.000000

# %%
# Identify and handle outliers
import matplotlib.pyplot as plt
plt.boxplot(s_df['Income'])
plt.title('Boxplot of Income')
plt.text(1.05, q1, f"Q1: {q1:.2f}", fontsize=10, color="r")
plt.text(1.05, q2, f"Q2: {q2:.2f}", fontsize=10, color="r")
plt.text(1.05, q3, f"Q3: {q3:.2f}", fontsize=10, color="r")
plt.show()

# %% [markdown]
# we can see in the above plot some outliers are present in the dataset
#
# So, lets calculate the IQR , min and max for the dataset, to detect the outliers

# %%
q1 = np.quantile(s_df['Income'], 0.25)
q2 = np.quantile(s_df['Income'], 0.5)
q3 = np.quantile(s_df['Income'], 0.75)
min=q1-1.5*(q3-q1)
max=q3+1.5*(q3-q1)
print("Q1 value is:", q1)
print("Q2 value is:", q2)
print("Q3 value is:", q3)
print("Min Value is:",min)
print("Max Value is:",max)
# Out:
# Q1 value is: 35538.75
# Q2 value is: 51381.5
# Q3 value is: 68289.75
# Min Value is: -13587.75
# Max Value is: 117416.25

# %%
#Counting how many values are present greater than max values
s_df[s_df['Income']>117416.25].count()
# Out:
# Id                     8
# Year_Birth             8
# Education              8
# Marital_Status         8
# Income                 8
# Kidhome                8
# Teenhome               8
# Dt_Customer            8
# Recency                8
# MntWines               8
# MntFruits              8
# MntMeatProducts        8
# MntFishProducts        8
# MntSweetProducts       8
# MntGoldProds           8
# NumDealsPurchases      8
# NumWebPurchases        8
# NumCatalogPurchases    8
# NumStorePurchases      8
# NumWebVisitsMonth      8
# Response               8
# Complain               8
# dtype: int64

# %% [markdown]
# We can see the maximum value is 117142.875 so beyond that value if any value is present in the dataset , those values we can consider as an outlier.

# %%
#dropping values greater than max values
s_df.drop(s_df[s_df['Income'] > 117416.25].index, inplace = True)

# %%
#Plotting box plot to show after dropping outliers
import matplotlib.pyplot as plt
plt.boxplot(s_df['Income'])
plt.title('Boxplot of Income')
plt.text(1.05, q1, f"Q1: {q1:.2f}", fontsize=10, color="r")
plt.text(1.05, q2, f"Q2: {q2:.2f}", fontsize=10, color="r")
plt.text(1.05, q3, f"Q3: {q3:.2f}", fontsize=10, color="r")
plt.show()

# %%
# Updated descriptive statistics after handling outliers
updated_statistics = s_df[key_variables].describe()
updated_statistics
# Out:
#         Year_Birth         Income  MntFishProducts  NumWebVisitsMonth
# count  2232.000000    2232.000000      2232.000000        2232.000000
# mean   1968.792563   51630.926971        37.644713           5.331541
# std      11.990340   20601.679542        54.689504           2.415275
# min    1893.000000    1730.000000         0.000000           0.000000
# 25%    1959.000000   35434.750000         3.000000           3.000000
# 50%    1970.000000   51381.500000        12.000000           6.000000
# 75%    1977.000000   68118.000000        50.000000           7.000000
# max    1996.000000  113734.000000       259.000000          20.000000

# %% [markdown]
# ## **Task 3:-**

# %%
#column 'MntGoldProds', follows an exponential distribution
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import expon

# Plot histogram
sns.histplot(s_df['MntGoldProds'], bins=20, kde=False, color='blue')
plt.title('Histogram of MntGoldProds')
plt.xlabel('Amount Spent on Gold Products')
plt.ylabel('Frequency')
# Out:
# Parameters for Binomial distribution: (0.0, 43.07142857142857)

# %%
# Fit the data to an exponential distribution and plot
params_exp = expon.fit(s_df['MntGoldProds'])
x = np.linspace(0, s_df['MntGoldProds'].max(), 100)
pdf_exp = expon.pdf(x, *params_exp)
plt.plot(x, pdf_exp * len(s_df['MntGoldProds']), color='blue', label='Exponential Fit')

plt.legend()
plt.show()

print(f'Parameters for Exponential distribution: {params_exp}')
print(f'Probablity density function: {pdf_exp}')
print(f'cummulative distribution function: {cdf_exp}')
# Out:
# Parameters for Exponential distribution: (0.0, 44.166218637992834)
# Probablity density function: [2.26417391e-02 2.08427061e-02 1.91866180e-02 1.76621168e-02
#  1.62587470e-02 1.49668842e-02 1.37776682e-02 1.26829431e-02
#  1.16752010e-02 1.07475306e-02 9.89356959e-03 9.10746133e-03
#  8.38381447e-03 7.71766605e-03 7.10444744e-03 6.53995302e-03
#  6.02031134e-03 5.54195857e-03 5.10161402e-03 4.69625771e-03
#  4.32310958e-03 3.97961049e-03 3.66340463e-03 3.37232338e-03
#  3.10437042e-03 2.85770806e-03 2.63064462e-03 2.42162285e-03
#  2.22920921e-03 2.05208408e-03 1.88903270e-03 1.73893680e-03
#  1.60076699e-03 1.47357568e-03 1.35649053e-03 1.24870856e-03
#  1.14949057e-03 1.05815609e-03 9.74078729e-04 8.96681857e-04
#  8.25434669e-04 7.59848532e-04 6.99473639e-04 6.43895923e-04
#  5.92734216e-04 5.45637639e-04 5.02283191e-04 4.62373534e-04
#  4.25634959e-04 3.91815501e-04 3.60683219e-04 3.32024598e-04
#  3.05643091e-04 2.81357765e-04 2.59002067e-04 2.38422673e-04
# ...

# %%
cdf_exp = expon.cdf(x, *params_exp)
plt.plot(x, cdf_exp * len(s_df['MntGoldProds']), color='blue', label='Exponential Fit')
print(f'cummulative distribution function: {cdf_exp}')
# Out:
# cummulative distribution function: [0.         0.07945648 0.15259964 0.21993109 0.28191262 0.33896932
#  0.3914925  0.43984236 0.48435052 0.52532221 0.56303844 0.59775787
#  0.62971862 0.65913987 0.68622342 0.71115501 0.73410561 0.75523265
#  0.774681   0.79258406 0.8090646  0.82423565 0.83820127 0.85105723
#  0.8628917  0.87378584 0.88381437 0.89304608 0.90154426 0.90936721
#  0.91656857 0.92319774 0.92930017 0.93491773 0.94008894 0.94484926
#  0.94923135 0.95326525 0.95697863 0.96039695 0.96354367 0.96644036
#  0.96910689 0.97156155 0.97382117 0.97590125 0.97781605 0.97957871
#  0.98120131 0.98269499 0.98406999 0.98533573 0.9865009  0.98757349
#  0.98856086 0.98946977 0.99030647 0.99107668 0.9917857  0.99243838
#  0.9930392  0.99359228 0.99410141 0.99457009 0.99500153 0.9953987
#  0.9957643  0.99610085 0.99641067 0.99669586 0.9969584  0.99720007
#  0.99742254 0.99762734 0.99781586 0.99798941 0.99814916 0.99829622
#  0.9984316  0.99855622 0.99867094 0.99877654 0.99887375 0.99896324
# ...

# %%
# checking if 'Income'  follow a Binomial distribution
from scipy.stats import binom
sns.histplot(s_df['Income'], bins=20, kde=False, color='blue')
plt.title('Histogram of income')
plt.xlabel('customers yearly household income')
plt.ylabel('Frequency')
plt.show()

# %%
#Calculate probabilities for Binomial distribution
prob_binomial = binom.pmf(k=2, n=10, p=0.2)  # Probability of getting exactly 2 successes in 10 trials with 0.2 probability of success
expected_value_binomial = binom.mean(n=10, p=0.2)  # Expected value for Binomial distribution

print(f'Probability for Binomial distribution: {prob_binomial}')
print(f'Expected value for Binomial distribution: {expected_value_binomial}')
# Out:
# Probability for Binomial distribution: 0.30198988800000004
# Expected value for Binomial distribution: 2.0

# %% [markdown]
# ## **Task 4: Insights and Customer Segmentation**

# %%
#Scatter plot between 'Income' and 'MntWines'
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Income', y='MntWines', data=s_df,color='green',hue='Income')
plt.xlabel('Income')
plt.ylabel('Amount Spent on Wines')
plt.title('Relationship between Income and Spending on Wines')
plt.show()
# Calculate covariance
covariance = np.cov(s_df['Income'],s_df['MntWines'])[0][1]
print("Covariance between Income and MntWines",covariance)

# Calculate correlation
correlation = np.corrcoef(s_df['Income'],s_df['MntWines'])[0][1]
print("Correlation between Income and MntWines",correlation)
# Out:
# Covariance between Income and MntWines 5052272.796103779
# Correlation between Income and MntWines 0.7281678306768851

# %% [markdown]
# We can infer from the following graph that there is a strong correlation between wine expenditure and income, indicating that a customer's likelihood of spending a significant amount of money on wine increases as his income rises.

# %%
#Scatter plot between 'Income' and 'MntFishProducts'
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Income', y='MntFishProducts', data=s_df,color='green',hue='Income')
plt.xlabel('Income')
plt.ylabel('Amount Spent on fish products')
plt.title('Relationship between Income and Spending on fish')
plt.show()
# Calculate covariance
covariance = np.cov(s_df['Income'],s_df['MntFishProducts'])[0][1]
print("Covariance between Income and MntFishProducts",covariance)

# Calculate correlation
correlation = np.corrcoef(s_df['Income'],s_df['MntFishProducts'])[0][1]
print("Correlation between Income and MntFishProducts",correlation)
# Out:
# Covariance between Income and MntFishProducts 620050.3021462403
# Correlation between Income and MntFishProducts 0.5503263549646347

# %% [markdown]
# The scatter plot above indicates a weak positive correlation between income and fish expenditure.

# %%
#Scatter plot between 'Income' and 'MntMeatProducts'
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Income', y='MntMeatProducts', data=s_df,color='green',hue='Income')
plt.xlabel('Income')
plt.ylabel('Amount Spent on meat products')
plt.title('Relationship between Income and Spending on meat')
plt.show()
# Calculate covariance
covariance = np.cov(s_df['Income'],s_df['MntMeatProducts'])[0][1]
print("Covariance between Income and MntMeatProducts",covariance)

# Calculate correlation
correlation = np.corrcoef(s_df['Income'],s_df['MntMeatProducts'])[0][1]
print("Correlation between Income and MntMeatProducts",correlation)
# Out:
# Covariance between Income and MntMeatProducts 3136735.1979244496
# Correlation between Income and MntMeatProducts 0.693962085127125

# %% [markdown]
# Here also Income and spending on meat is positively correlated, suggesting that an increase in client income may lead to a rise in meat sales.

# %%
#Scatter plot between 'Income' and 'MntFruits'
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Income', y='MntFruits', data=s_df,color='green',hue='Income')
plt.xlabel('Income')
plt.ylabel('Amount Spent on fruits')
plt.title('Relationship between Income and Spending on fruits')
plt.show()
# Calculate covariance
covariance = np.cov(s_df['Income'],s_df['MntFruits'])[0][1]
print("Covariance between Income and MntFruits",covariance)

# Calculate correlation
correlation = np.corrcoef(s_df['Income'],s_df['MntFruits'])[0][1]
print("Correlation between Income and MntFruits",correlation)
# Out:
# Covariance between Income and MntFruits 439644.17391364597
# Correlation between Income and MntFruits 0.5358962680849151

# %% [markdown]
# From the above graph we can see that income and fruit spent has weak positive correlation

# %%
#Scatter plot between 'Income' and 'MntSweetProducts'
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Income', y='MntSweetProducts', data=s_df,color='green',hue='Income')
plt.xlabel('Income')
plt.ylabel('Amount Spent on sweet products')
plt.title('Relationship between Income and Spending on sweet products')
plt.show()
# Calculate covariance
covariance = np.cov(s_df['Income'],s_df['MntSweetProducts'])[0][1]
print("Covariance between Income and MntSweetProducts",covariance)

# Calculate correlation
correlation = np.corrcoef(s_df['Income'],s_df['MntSweetProducts'])[0][1]
print("Correlation between Income and MntSweetProducts",correlation)
# Out:
# Covariance between Income and MntSweetProducts 468179.60503852554
# Covariance between Income and MntSweetProducts 0.5499113142469823

# %% [markdown]
# From the above graph we can see that income and sweet product spent has weak positive correlation

# %%
#Scatter plot between 'Income' and 'MntGoldProds'
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Income', y='MntGoldProds', data=s_df,color='green',hue='Income')
plt.xlabel('Income')
plt.ylabel('Amount Spent on gold products')
plt.title('Relationship between Income and Spending on gold products')
plt.show()

# Calculate covariance
covariance = np.cov(s_df['Income'],s_df['MntGoldProds'])[0][1]
print("Covariance between Income and MntGoldProds",covariance)

# Calculate correlation
correlation = np.corrcoef(s_df['Income'],s_df['MntGoldProds'])[0][1]
print("Correlation between Income and MntGoldProds",correlation)
# Out:
# Covariance between Income and MntGoldProds 444672.69793529285
# Covariance between Income and MntGoldProds 0.4134565317180791

# %% [markdown]
# From the above graph we can see that income and gold product spent has weak positive correlation

# %% [markdown]
# ## **Task 5**

# %%
# Visualization of Customer Segments
plt.figure(figsize=(12, 8))

# Example: Bar chart for offer acceptance by Education level
sns.countplot(x='Education', hue='Response', data=s_df)
plt.title('Offer Acceptance by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Number of Customers')

plt.show()

# %% [markdown]
# We can infer from the graphic above that the offer to acceptance ratio for graduation-level students is higher than that of other students.

# %%
#Count plot for segmentation based on 'Marital_Status'
plt.figure(figsize=(10, 6))
sns.countplot(x='Marital_Status', data=s_df, hue='Response')
plt.xlabel('Marital_Status')
plt.ylabel('Count')
plt.title('Customer Segmentation based on Marital_status')
plt.show()

# %% [markdown]
# Among all marital status groups, married individuals are more likely to have declined offer during the previous campaign.

# %%
# Example: Bar plot between 'Marital_Status' and 'MntWines'
plt.figure(figsize=(10, 6))
sns.barplot(x='Marital_Status', y='MntWines', data=s_df, errorbar=None)  # ci=None removes confidence intervals
plt.xlabel('Marital Status')
plt.ylabel('Amount Spent on Wines')
plt.title('Bar Plot: Marital Status vs Amount Spent on Wines')
plt.show()

# %% [markdown]
# The bar chart above shows that while all customer types spend a adequate amount on wine, but widows spend more than other customer kinds.

# %%
# Bar Plot for Marital_Status vs Recency
plt.figure(figsize=(12, 6))
sns.barplot(x='Marital_Status', y='Recency', data=s_df, palette='viridis')
plt.title('Marital Status vs Recency')
plt.xlabel('Marital Status')
plt.ylabel('Recency')
plt.show()

# %% [markdown]
# According to the plot above, Absurd has a greater recency rate than other categories under marital_status.

# %%
# Side-by-Side Bar Plot for Purchases Comparison
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.countplot(x='NumWebPurchases', data=s_df, color='skyblue')
plt.title('Number of Web Purchases')

plt.subplot(1, 2, 2)
sns.countplot(x='NumStorePurchases', data=s_df, color='salmon')
plt.title('Number of Store Purchases')

plt.tight_layout()
plt.show()

# Scatter Plot for Correlation Analysis
plt.figure(figsize=(8, 6))
sns.scatterplot(x='NumWebVisitsMonth', y='NumWebPurchases', data=s_df, color='green')
plt.title('Correlation between Web Visits and Web Purchases')
plt.xlabel('Number of Web Visits in Last Month')
plt.ylabel('Number of Web Purchases')
plt.show()

# %% [markdown]
# Customers prefer to buy from the market rather than the web, as seen by the higher number of in-store purchases than web purchases.

# %%
# Customer Behavior and Spending Patterns
product_columns = ['MntFishProducts', 'MntMeatProducts', 'MntFruits', 'MntSweetProducts', 'MntWines', 'MntGoldProds']
sns.pairplot(s_df, vars=product_columns)
plt.show()

# %% [markdown]
# # **Insights and Recommendations:**
#
# **Education Demographics:**
#
# Insight:
#
# Graduation-level students constitute a significant portion of the customer base.
#
# Recommendation:
#
# Develop targeted marketing campaigns tailored to the preferences and behaviors of graduation-level students.
#
# **Marital Status and Birth Years:**
#
# Insight:
#
#  Majority of consumers in the dataset are married, with birth years typically falling between 1960 and 1980.
#
# Recommendation:
#
# Consider crafting promotions and offers that resonate with the preferences and life stages of married individuals.
#
# **Campaign Response Dynamics:**
#
# Insight:
#
# A high number of customers declined the offer in the last campaign, overshadowing those who accepted it.
#
# Recommendation:
#
# Investigate reasons behind the decline and refine future campaigns to address customer concerns or objections.
#
# **Wine Expenditure and Income:**
#
# Insight:
#
# Strong correlation between wine expenditure and income.
#
# Recommendation:
#
# Target customers with higher incomes for wine-related promotions and offerings.
#
# **Income and Product Spending:**
#
# Insight:
#
#  Positive correlation between income and spending on meat, fish, fruits, and gold products.
#
# Recommendation:
#
# Tailor product promotions based on income levels, emphasizing higher-end products for customers with increased income.
#
# **Offer Acceptance Ratio by Education:**
#
# Insight:
#
# Graduation-level students show a higher offer acceptance ratio.
#
# Recommendation:
#
# Strategically design offers that appeal to the preferences and behaviors of graduation-level students to maximize acceptance rates.
#
# **Marital Status and Offer Decline:**
#
# Insight:
#
# Married individuals are more likely to have declined the offer in the previous campaign.
#
# Recommendation:
#
#  Customize future offers, taking into account the preferences and priorities of married customers to increase acceptance rates.
#
# **Widows' Spending Patterns:**
#
# Insight:
#
#  Widows tend to spend more on wine products compared to other customer segments.
#
# Recommendation:
#
# Design promotions that specifically cater to the preferences of widows, potentially increasing their spending.
#
# **Recency Rate by Marital Status:**
#
# Insight:
#
# "Absurd" marital status category exhibits a higher recency rate.
#
# Recommendation:
#
# Explore and capitalize on the reasons behind the higher recency rate in the "Absurd" category for targeted marketing.
#
# **Purchase Preferences:**
#
# Insight:
#
# Customers prefer in-store purchases over web purchases.
#
# Recommendation:
#
# Optimize in-store experiences and promotions to align with customer preferences.

# %% [markdown]
# # **Conclusion:**
#
# The analysis of the dataset has provided valuable insights into customer behavior, preferences, and correlations between different factors. The recommendations outlined above aim to optimize marketing strategies, enhance customer engagement, and improve offer acceptance rates.
#
# Continual monitoring of customer responses, feedback, and market dynamics will be crucial for refining these recommendations and ensuring their effectiveness over time. By adopting a customer-centric approach and leveraging data-driven insights, the company can strengthen its position in the market and foster long-term customer relationships.
